# %%
from sqlalchemy import (
    MetaData,
    Table,
    Column,
    Integer,
    String,
    Boolean,
    Float,
    text,
)
from egomimic.utils.aws.aws_sql import (
    TableRow,
    add_episode,
    update_episode,
    create_default_engine,
    episode_hash_to_table_row,
    delete_episodes,
    episode_table_to_df,
    delete_all_episodes,
)

# %%
engine = create_default_engine()
# Out:
# Tables in schema 'app': ['episodes']

# %%
def drop_table(table_name):
    with engine.connect() as connection:
        connection.execute(text(f"DROP TABLE IF EXISTS app.{table_name} CASCADE;"))
        connection.commit()
    print(f"Dropped table '{table_name}' from schema 'app' if it existed.")


# drop_table("episodes")

# %%
def create_table():
    metadata = MetaData(schema="app")

    Table(
        "episodes",
        metadata,
        Column("episode_hash", String, primary_key=True),
        Column("operator", String),
        Column("lab", String),
        Column("num_frames", Integer),
        Column("task", String),
        Column("task_description", String),
        Column("scene", String),
        Column(
            "objects", String
        ),  # Store as JSON or comma-separated list of object names
        Column("processed_path", String),
        Column("mp4_path", String),
        Column("is_deleted", Boolean),
        Column("embodiment", String),
        Column("robot_name", String),
        Column("is_eval", Boolean),
        Column("eval_score", Float),
        Column("eval_success", Boolean),
    )

    metadata.create_all(engine)
    print("Created table 'episodes' in schema 'app'.")


# create_table()

# %%
# Add Episode Test
episode = TableRow(
    episode_hash=1761408819,
    operator="test",
    lab="lab-x",
    num_frames=-1,
    task="bimanual_test",
    task_description="Dummy row for table inspection",
    scene="kitchen",
    objects="cup,plate,spoon",
    processed_path="",
    mp4_path="",
    embodiment="aria",
    robot_name="",
    is_eval=False,
    eval_score=0.0,
    eval_success=False,
)

# %%
add_episode(engine, episode)

# %%
df = episode_table_to_df(engine)
df
# Out:
#                    episode_hash operator  lab  num_frames          task  \
# 0    2025-10-29-21-54-36-200000  Aniketh  rl2          -1  fold clothes
# 1    2025-10-29-21-54-36-217000  Aniketh  rl2          -1  fold clothes
# 2    2025-10-29-22-01-54-605000    Jenny  rl2          -1  fold clothes
# 3    2025-10-29-21-54-36-213000  Aniketh  rl2          -1  fold clothes
# 4    2025-10-29-21-54-36-196000  Aniketh  rl2          -1  fold clothes
# ..                          ...      ...  ...         ...           ...
# 279  2025-10-29-22-06-00-420000   Pranav  rl2          -1  fold clothes
# 280  2025-10-29-22-06-00-436000   Pranav  rl2          -1  fold clothes
# 281  2025-10-29-22-03-53-625000  Aniketh  rl2          -1  fold clothes
# 282  2025-10-29-22-01-11-723000    Baoyu  rl2          -1  fold clothes
# 283  2025-10-29-22-02-26-819000    Jenny  rl2          -1  fold clothes
#
#     task_description scene                                            objects  \
# 0    folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# 1    folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# 2    folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# 3    folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# 4    folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# ..               ...   ...                                                ...
# 279  folding clothes     7  {"short sleeve shirts","long sleeve shirts",sh...
# 280  folding clothes    16  {"short sleeve shirts","long sleeve shirts",sh...
# 281  folding clothes     7  {"short sleeve shirts","long sleeve shirts",sh...
# 282  folding clothes     1  {"short sleeve shirts","long sleeve shirts",sh...
# 283  folding clothes    10  {"short sleeve shirts","long sleeve shirts",sh...
#
#     processed_path mp4_path  is_deleted embodiment robot_name  is_eval  \
# 0                                 False       aria       aria    False
# 1                                 False       aria       aria    False
# 2                                 False       aria       aria    False
# 3                                 False       aria       aria    False
# 4                                 False       aria       aria    False
# ..             ...      ...         ...        ...        ...      ...
# 279                               False       aria       aria    False
# 280                               False       aria       aria    False
# 281                               False       aria       aria    False
# 282                               False       aria       aria    False
# 283                               False       aria       aria    False
#
#      eval_score  eval_success
# 0          -1.0          True
# 1          -1.0          True
# 2          -1.0          True
# 3          -1.0          True
# 4          -1.0          True
# ..          ...           ...
# 279        -1.0          True
# 280        -1.0          True
# 281        -1.0          True
# 282        -1.0          True
# 283        -1.0          True
#
# [284 rows x 16 columns]

# %%
## WARNING DO NOT RUN THIS IT WILL DELETE ALL EPISODES FROM THE TABLE

delete_all_episodes(engine)

# %%
episode.operator = "simar"
update_episode(engine, episode)

# %%
episode_hash_to_table_row(engine, 123456)

# %%
delete_episodes(engine, [123456, 123457])
